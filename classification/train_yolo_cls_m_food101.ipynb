# %%
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu130
# Requirement already satisfied: torch in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (2.10.0+cu130)
# Requirement already satisfied: torchvision in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (0.25.0+cu130)
# Requirement already satisfied: filelock in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torch) (70.2.0)
# Requirement already satisfied: numpy in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pavel\appdata\local\programs\python\python314\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~orch (c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages)

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.10.0+cu130
# True

# %%
import os
import cv2
import numpy as np
import yaml
import shutil
from tqdm import tqdm
from pathlib import Path
from ultralytics import YOLO

# %%
model = YOLO('yolo26m-cls.pt')

results = model.train(
    data='C:/training/yolo_food101_ready',
    epochs=100,
    imgsz=256,
    batch=128,
    amp=True,
    workers=8, 
    device=0,   
    project="food101_cls_yolo",
    name="yolo26_food101cls_run",
    verbose=True,
    plots=True,
    exist_ok=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.37 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.22  Python-3.14.2 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:/training/yolo_food101_ready, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26_food101cls_run4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=food101_cls_yolo, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\training\classification\runs\classify\food101_cls_yolo\yolo26_food101cls_run4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\training\yolo_food101_ready\train... found 73990 images in 101 classes
# val: C:\training\yolo_food101_ready\val... found 18548 images in 101 classes
# test: None...
# Overriding model.yaml nc=1000 with nc=101
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    787301  ultralytics.nn.modules.head.Classify         [512, 101]
# YOLO26m-cls summary: 106 layers, 10,482,597 parameters, 10,482,597 gradients, 39.7 GFLOPs
# Transferred 294/296 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 147.930.9 MB/s, size: 46.0 KB)
# train: Scanning C:\training\yolo_food101_ready\train... 73990 images, 0 corrupt: 100% ━━━━━━━━━━━━ 73990/73990 28.2Git/s 0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 137.048.5 MB/s, size: 51.3 KB)
# val: Scanning C:\training\yolo_food101_ready\val... 18548 images, 0 corrupt: 100% ━━━━━━━━━━━━ 18548/18548 5.6Git/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 49 weight(decay=0.0), 50 weight(decay=0.0005), 50 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\training\classification\runs\classify\food101_cls_yolo\yolo26_food101cls_run4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100      3.39G      3.948         64        224: 65% ━━━━━━━╸──── 747/1157 7.8it/s 2:08<52.6s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 model = YOLO('yolo26m-cls.pt')
# ----> 3 results = model.train(
#       4     data='C:/training/yolo_food101_ready',
#       5     epochs=100,
#       6     imgsz=224,
#       7     batch=64,
#       8     device=0,
#       9     project="food101_cls_yolo",
#      10     name="yolo26_food101cls_run",
#      11     verbose=True,
#      12     plots=True
#      13 )
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\ultralytics\engine\model.py:777, in Model.train(self, trainer, **kwargs)
#     774     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     775     self.model = self.trainer.model
# --> 777 self.trainer.train()
#     778 # Update model and cfg after training
#     779 if RANK in {-1, 0}:
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\ultralytics\engine\trainer.py:244, in BaseTrainer.train(self)
#     241         ddp_cleanup(self, str(file))
#     243 else:
# --> 244     self._do_train()
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\ultralytics\engine\trainer.py:465, in BaseTrainer._do_train(self)
#     463     break  # restart epoch loop with reduced batch size
#     464 if ni - last_opt_step >= self.accumulate:
# --> 465     self.optimizer_step()
#     466     last_opt_step = ni
#     468     # Timed stopping
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\ultralytics\engine\trainer.py:725, in BaseTrainer.optimizer_step(self)
#     723 self.scaler.unscale_(self.optimizer)  # unscale gradients
#     724 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)
# --> 725 self.scaler.step(self.optimizer)
#     726 self.scaler.update()
#     727 self.optimizer.zero_grad()
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\amp\grad_scaler.py:463, in GradScaler.step(self, optimizer, *args, **kwargs)
#     457     self.unscale_(optimizer)
#     459 assert len(optimizer_state["found_inf_per_device"]) > 0, (
#     460     "No inf checks were recorded for this optimizer."
#     461 )
# --> 463 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     465 optimizer_state["stage"] = OptState.STEPPED
#     467 return retval
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\amp\grad_scaler.py:357, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     355 retval: Optional[float] = None
#     356 if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 357     retval = optimizer.step(*args, **kwargs)
#     358 return retval
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\optim\lr_scheduler.py:166, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     164 opt = opt_ref()
#     165 opt._opt_called = True  # type: ignore[union-attr]
# --> 166 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\optim\optimizer.py:526, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     521             raise RuntimeError(
#     522                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     523             )
#     525 # pyrefly: ignore [invalid-param-spec]
# --> 526 out = func(*args, **kwargs)
#     527 self._optimizer_step_code()
#     529 # call optimizer step post hooks
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\ultralytics\optim\muon.py:218, in MuSGD.step(self, closure)
#     215     state["momentum_buffer"] = torch.zeros_like(p)
#     216     state["momentum_buffer_SGD"] = torch.zeros_like(p)
# --> 218 update = muon_update(
#     219     grad, state["momentum_buffer"], beta=group["momentum"], nesterov=group["nesterov"]
#     220 )
#     221 p.add_(update.reshape(p.shape), alpha=-(lr * self.muon))
#     223 # SGD update
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\ultralytics\optim\muon.py:94, in muon_update(grad, momentum, beta, nesterov)
#      92 if update.ndim == 4:  # for the case of conv filters
#      93     update = update.view(len(update), -1)
# ---> 94 update = zeropower_via_newtonschulz5(update)
#      95 update *= max(1, grad.size(-2) / grad.size(-1)) ** 0.5
#      96 return update
#
# File c:\Users\pavel\AppData\Local\Programs\Python\Python314\Lib\site-packages\ultralytics\optim\muon.py:53, in zeropower_via_newtonschulz5(G, eps)
#      51     A = X @ X.T
#      52     B = b * A + c * A @ A
# ---> 53     X = a * X + B @ X
#      54 if G.size(0) > G.size(1):
#      55     X = X.T
#
# KeyboardInterrupt:
