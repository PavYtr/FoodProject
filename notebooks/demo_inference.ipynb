# %% [markdown]
# # FoodProject demo inference
#
# Notebook only demonstrates the application pipeline. Inference logic lives in `src/food_project`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from food_project.pipeline import FoodNutritionPipeline

pipeline = FoodNutritionPipeline()
pipeline.load_models()

# %%
image_path = ROOT / "examples" / "example.jpg"

if image_path.exists():
    result = pipeline.predict(image_path)
    print(result.summary_text())
    print(result.warnings_text())
else:
    print(f"Put a demo image at {image_path}")
